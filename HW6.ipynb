# %%
import pandas as pd

df = pd.DataFrame({'Название': ['Земля', 'Луна', 'Марс'], 'Масса': [1, 0.606, 0.107]})
print(df)
df.hist("Масса")
df.info()
# Out:
#   Название  Масса
# 0    Земля  1.000
# 1     Луна  0.606
# 2     Марс  0.107
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Название  3 non-null      object
#  1   Масса     3 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 176.0+ bytes
